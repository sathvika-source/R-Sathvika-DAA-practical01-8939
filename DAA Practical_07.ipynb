# %% [markdown]
# <a href="https://colab.research.google.com/github/sathvika-source/R-Sathvika-DAA-practical01-8939/blob/main/DAA%20Practical_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

def coin_change(coins, amount):

    dp = [float('inf')] * (amount + 1)

    dp[0] = 0


    for i in range(1, amount + 1):

        for coin in coins:

            if i - coin >= 0:

                dp[i] = min(dp[i], 1 + dp[i - coin])


    return dp[amount] if dp[amount] != float('inf') else -1

# Example usage:
coins = [1, 2, 5]
amount = 11
start_time = time.perf_counter()

min_coins = coin_change(coins, amount)

end_time = time.perf_counter()

execution_time = end_time - start_time

print(f"Coins available: {coins}")
print(f"Target amount: {amount}")
print(f"Minimum coins needed: {min_coins}")
print(f"Execution Time: {execution_time} seconds")
print(f"Time Complexity: O(amount * len(coins))")
print(f"Space Complexity: O(amount)")
# Out:
# Coins available: [1, 2, 5]
# Target amount: 11
# Minimum coins needed: 3
# Execution Time: 7.544999994024693e-05 seconds
# Time Complexity: O(amount * len(coins))
# Space Complexity: O(amount)
