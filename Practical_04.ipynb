# %% [markdown]
# <a href="https://colab.research.google.com/github/sathvika-source/R-Sathvika-DAA-practical01-8939/blob/main/Practical_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

def factorial_iterative(n):
    factorial = 1

    for i in range(1, n + 1):
        factorial = factorial * i

    return factorial


n = int(input("Enter a number: "))

start_time = time.perf_counter()

result = factorial_iterative(n)

end_time = time.perf_counter()

execution_time = end_time - start_time

print("Factorial =", result)
print("Execution Time =", execution_time, "seconds")
print("Time Complexity = O(n)")
print("Space Complexity = O(1)")
# Out:
# Enter a number: 6
# Factorial = 720
# Execution Time = 8.281099997020647e-05 seconds
# Time Complexity = O(n)
# Space Complexity = O(1)

# %%
import time

def factorial_recursive(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial_recursive(n - 1)


n = int(input("Enter a number: "))

start_time = time.perf_counter()

result = factorial_recursive(n)

end_time = time.perf_counter()

execution_time = end_time - start_time

print("Factorial =", result)
print("Execution Time =", execution_time, "seconds")
print("Time Complexity = O(n)")
print("Space Complexity = O(n)")
# Out:
# Enter a number: 6
# Factorial = 720
# Execution Time = 0.00012048599990066577 seconds
# Time Complexity = O(n)
# Space Complexity = O(n)
