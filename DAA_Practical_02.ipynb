# %% [markdown]
# <a href="https://colab.research.google.com/github/sathvika-source/R-Sathvika-DAA-practical01-8939/blob/main/DAA_Practical_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# ------------------ Linear Search ------------------
def linear_search(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1


# ------------------ Binary Search ------------------
def binary_search(arr, key):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1

    return -1


# ------------------ Main Program ------------------
# Input list
arr = list(map(int, input("Enter elements (space-separated): ").split()))

# Sort the array for Binary Search
sorted_arr = sorted(arr)

key = int(input("Enter the element to search: "))

# -------- Linear Search --------
start = time.perf_counter()

index = linear_search(arr, key)

end = time.perf_counter()

print("\n----- Linear Search -----")
if index != -1:
    print(f"Element found at index {index}")
else:
    print("Element not found")

print(f"Execution Time: {(end - start):.10f} seconds")
print("Best Case Time Complexity: O(1)")
print("Average Case Time Complexity: O(n)")
print("Worst Case Time Complexity: O(n)")


# -------- Binary Search --------
start = time.perf_counter()

index = binary_search(sorted_arr, key)

end = time.perf_counter()

print("\n----- Binary Search -----")
print("Sorted Array:", sorted_arr)

if index != -1:
    print(f"Element found at index {index} (in sorted array)")
else:
    print("Element not found")

print(f"Execution Time: {(end - start):.10f} seconds")
print("Best Case Time Complexity: O(1)")
print("Average Case Time Complexity: O(log n)")
print("Worst Case Time Complexity: O(log n)")
# Out:
# Enter elements (space-separated): 3 4 5 6 8 9
# Enter the element to search: 9
#
# ----- Linear Search -----
# Element found at index 5
# Execution Time: 0.0000915210 seconds
# Best Case Time Complexity: O(1)
# Average Case Time Complexity: O(n)
# Worst Case Time Complexity: O(n)
#
# ----- Binary Search -----
# Sorted Array: [3, 4, 5, 6, 8, 9]
# Element found at index 5 (in sorted array)
# Execution Time: 0.0000767120 seconds
# Best Case Time Complexity: O(1)
# Average Case Time Complexity: O(log n)
# Worst Case Time Complexity: O(log n)
